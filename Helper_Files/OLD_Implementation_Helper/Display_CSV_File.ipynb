# %%
import pandas as pd
# Out:
# /users/3/hassa940/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv("results_per_section/gram8_plural" + "_results.csv")

# %%
# load and stack the fourteen result files
root = Path("/results_per_section")
dfs = [pd.read_csv(f"resultsfp", sep="\t") for fp in root.glob("*.tsv")]
all_results = pd.concat(dfs, ignore_index=True)

# %%
df.sort_values(by='overall_accuracy', ascending=False)
# Out:
#             word1       word2     word3  true_word       section  \
# 51946       woman       women      road      roads  gram8-plural
# 51777   pineapple  pineapples       cat       cats  gram8-plural
# 51493       mango     mangoes      bird      birds  gram8-plural
# 51494       mango     mangoes    bottle    bottles  gram8-plural
# 51495       mango     mangoes  building  buildings  gram8-plural
# ...           ...         ...       ...        ...           ...
# 115434      mango     mangoes     child   children  gram8-plural
# 115433      mango     mangoes       cat       cats  gram8-plural
# 115432      mango     mangoes       car       cars  gram8-plural
# 115431      mango     mangoes  building  buildings  gram8-plural
# 55943       woman       women     snake     snakes  gram8-plural
#
#             candidate_1        candidate_2        candidate_3    candidate_4  \
# 51946           highway           highways            roadway       roadways
# ...

# %%
df.shape
# Out:
# (81200, 19)

# %%
df['overall_accuracy'].unique()
# Out:
# array([0.])

# %%
df.groupby(['freq_subset', 'rcond', 'measure'])['overall_accuracy'].first().reset_index()
# Out:
#     freq_subset  rcond                     measure  overall_accuracy
# 0         10000  0.001          euclidean_distance               0.0
# 1         10000  0.001          mahalanobis_cosine               0.0
# 2         10000  0.001        mahalanobis_distance               0.0
# 3         10000  0.001  mahalanobis_shifted_cosine               0.0
# 4         10000  0.001                naive_cosine               0.0
# ..          ...    ...                         ...               ...
# 95       100000  0.020          euclidean_distance               0.0
# 96       100000  0.020          mahalanobis_cosine               0.0
# 97       100000  0.020        mahalanobis_distance               0.0
# 98       100000  0.020  mahalanobis_shifted_cosine               0.0
# 99       100000  0.020                naive_cosine               0.0
#
# [100 rows x 4 columns]

# %%
df.groupby(['freq_subset', 'rcond', 'measure'])['overall_accuracy'].first().reset_index().sort_values(by='overall_accuracy', ascending=False)
# Out:
#     freq_subset  rcond                     measure  overall_accuracy
# 96       100000  0.020          mahalanobis_cosine          0.082975
# 91       100000  0.010          mahalanobis_cosine          0.082975
# 86       100000  0.005          mahalanobis_cosine          0.082975
# 81       100000  0.001          mahalanobis_cosine          0.082975
# 88       100000  0.005  mahalanobis_shifted_cosine          0.062692
# ..          ...    ...                         ...               ...
# 57        30000  0.020        mahalanobis_distance          0.004917
# 62        50000  0.001        mahalanobis_distance          0.004302
# 77        50000  0.020        mahalanobis_distance          0.004302
# 67        50000  0.005        mahalanobis_distance          0.004302
# 72        50000  0.010        mahalanobis_distance          0.004302
#
# [100 rows x 4 columns]
